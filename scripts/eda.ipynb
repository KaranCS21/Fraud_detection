# %% [markdown]
# ## Data Loading and Basic Info

# %%
import pandas as pd

# %%
# Load the dataset  
df = pd.read_csv('..\data\creditcard.csv')
# Out:
# <>:2: SyntaxWarning: invalid escape sequence '\d'
# <>:2: SyntaxWarning: invalid escape sequence '\d'
# C:\Users\DELL\AppData\Local\Temp\ipykernel_18952\4036529437.py:2: SyntaxWarning: invalid escape sequence '\d'
#   df = pd.read_csv('..\data\creditcard.csv')

# %%
# Display basic info about the dataset
print("Dataset shape:", df.shape)
print("First five rows of the dataset:")
print(df.head())
# Out:
# Dataset shape: (284807, 31)
# First five rows of the dataset:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# ...

# %%
# Get the column names and data types
print("\nColumn names and data types:")
print(df.dtypes)
# Out:
# Column names and data types:
# Time      float64
# V1        float64
# V2        float64
# V3        float64
# V4        float64
# V5        float64
# V6        float64
# V7        float64
# V8        float64
# V9        float64
# V10       float64
# V11       float64
# V12       float64
# V13       float64
# V14       float64
# V15       float64
# V16       float64
# V17       float64
# V18       float64
# V19       float64
# V20       float64
# V21       float64
# V22       float64
# V23       float64
# V24       float64
# V25       float64
# V26       float64
# V27       float64
# V28       float64
# Amount    float64
# Class       int64
# dtype: object

# %%
# Check for missing values
print("\nChecking for missing values:")
print(df.isnull().sum())
# Out:
# Checking for missing values:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %% [markdown]
# ## Class Distribution
# Credit card fraud detection is an imbalanced classification problem. It’s important to visualize how many fraudulent (1) vs. non-fraudulent (0) transactions are in the dataset.

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
# Check the class distribution (fraud vs non-fraud)
print("\nClass distribution:")
class_counts = df['Class'].value_counts()
print(class_counts)
# Out:
# Class distribution:
# Class
# 0    284315
# 1       492
# Name: count, dtype: int64

# %%
# Visualize the class distribution
sns.countplot(x='Class', data=df)
plt.title("Class Distribution: Fraud vs Non-Fraud")
plt.show()

# %% [markdown]
# ## Summary Statistics
# get a sense of the dataset’s numerical values by calculating summary statistics.

# %%
# Display summary statistics for numerical features
print("\nSummary statistics for numerical features:")
print(df.describe())
# Out:
# Summary statistics for numerical features:
#                 Time            V1            V2            V3            V4  \
# count  284807.000000  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean    94813.859575  1.168375e-15  3.416908e-16 -1.379537e-15  2.074095e-15
# std     47488.145955  1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00
# min         0.000000 -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00
# 25%     54201.500000 -9.203734e-01 -5.985499e-01 -8.903648e-01 -8.486401e-01
# 50%     84692.000000  1.810880e-02  6.548556e-02  1.798463e-01 -1.984653e-02
# 75%    139320.500000  1.315642e+00  8.037239e-01  1.027196e+00  7.433413e-01
# max    172792.000000  2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01
#
#                  V5            V6            V7            V8            V9  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean   9.604066e-16  1.487313e-15 -5.556467e-16  1.213481e-16 -2.406331e-15
# ...

# %% [markdown]
# ## Correlation Matrix
# it’s helpful to visualize the correlation between features, especially if we plan to apply dimensionality
# reduction techniques like PCA.

# %%
# Visualizing the correlation matrix
plt.figure(figsize=(12,8))
sns.heatmap(df.corr(), annot=False, cmap='coolwarm')
plt.title("Correlation Matrix of Features")
plt.show()
